# %%
import pandas as pd

# %%
df = pd.read_json("logs1.json")
df
# Out:
#       ID  applicant_id                     status            Created  \
# 0      5          2496    0 - Record disqualified  01/30/2024  23:35
# 1      6          2463              0 - CV Failed  01/31/2024  12:17
# 2      7          2219              0 - CV Passed  01/31/2024  12:19
# 3      8          2462              0 - CV Passed  01/31/2024  12:24
# 4      9          1936              0 - CV Failed  01/31/2024  12:26
# ..   ...           ...                        ...                ...
# 938  943          2677              0 - CV Passed  04/19/2024  10:42
# 939  944          2787              0 - CV Passed  04/19/2024  10:42
# 940  945          1868  2 - Tech Interview Failed  04/19/2024  10:49
# 941  946          1932  2 - Tech Interview Passed  04/19/2024  10:49
# 942  947          2580          1 - Ready To Call  04/19/2024  10:49
#
#                   log_user
# 0      Null log user Value
# 1      Null log user Value
# 2      Null log user Value
# ...

# %%
df.to_excel("logs.xlsx")
